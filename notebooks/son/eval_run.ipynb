# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install qwen-vl-utils
# Out:
# ...
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/base_command.py", line 179, in exc_logging_wrapper
#     status = run_func(*args)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/req_command.py", line 67, in wrapper
#     return func(self, options, args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/commands/install.py", line 447, in run
# ^C

# %%
cd /content/drive/Othercomputers/mynotebook/multimodal-anomaly-report-generation
# Out:
# /content/drive/Othercomputers/mynotebook/multimodal-anomaly-report-generation

# %%
# !python scripts/run_experiment.py --config configs/experiment.yaml
# Out:
# ...
# MMAD Experiment Runner
# ...
# Experiment:  patchcore_qwen_1shot
# LLM:         qwen
# AD model:    patchcore
# Few-shot:    1
# Template:    Random_template
# Image size:  (700, 700)
# Max images:  all
# Data root:   /content/drive/Othercomputers/mynotebook/multimodal-anomaly-report-generation/dataset/MMAD
# Output:      outputs/eval/answers_1_shot_qwen_Random_template_with_patchcore.json
# ...
#
# AD predictions already exist: outputs/eval/patchcore_predictions.json
# Loaded 5 AD predictions
#
# Stratified sampling: 3장/폴더, 33폴더
#   Total: 4224 -> Sampled: 99 (normal=30, anomaly=69)
# Total images: 99 (available: 4224)
#
# Evaluating:   0%|                                                            | 0/99 [00:00<?, ?it/s]Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
#
# ...
#
# Fetching 5 files: 100% 5/5 [00:00<00:00, 28688.81it/s]
#
# Download complete: : 0.00B [00:00, ?B/s]
#
# ...
